# %% [markdown]
# # proyecto-1b-freire-alex

# %% [markdown]
# ## Indicadores de desarrollo mundial

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('.//data/desarrollo-mundial.csv')
data.shape
# Out:
# (422136, 64)

# %%
data
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# 5        Arab World          ARB
# 6        Arab World          ARB
# 7        Arab World          ARB
# 8        Arab World          ARB
# 9        Arab World          ARB
# 10       Arab World          ARB
# 11       Arab World          ARB
# 12       Arab World          ARB
# 13       Arab World          ARB
# 14       Arab World          ARB
# 15       Arab World          ARB
# 16       Arab World          ARB
# 17       Arab World          ARB
# 18       Arab World          ARB
# 19       Arab World          ARB
# 20       Arab World          ARB
# 21       Arab World          ARB
# 22       Arab World          ARB
# 23       Arab World          ARB
# 24       Arab World          ARB
# 25       Arab World          ARB
# 26       Arab World          ARB
# ...

# %% [markdown]
# ### Cantidad de países en el dataset

# %%
paises=data['Country Name'].unique().tolist()
len(paises)
# Out:
# 264

# %% [markdown]
# ### Cantidad de código de países en el dataset

# %%
countries=data['Country Code'].unique().tolist()
len(countries)
# Out:
# 264

# %% [markdown]
# ### Cantidad de indicadores considerados

# %%
indicadores=data['Indicator Name'].unique().tolist()
len(indicadores)
# Out:
# 1599

# %% [markdown]
# ### Cantidad de datos registrados en el año 1960

# %%
ano_1960=data['1960'].unique().tolist()
len(ano_1960)
# Out:
# 33954

# %% [markdown]
# ### Cantidad de datos registrados en el año 2018

# %%
ano_2018=data['2018'].unique().tolist()
len(ano_2018)
# Out:
# 20005

# %% [markdown]
# ### Emisiones de CO2 en Ecuador

# %%
co2_indicador='CO2 emissions \(metric tons per capita\)'
co2_codigo_pais='ECU'
filtro1=data['Indicator Name'].str.contains(co2_indicador)
filtro2=data['Country Code'].str.contains(co2_codigo_pais)

# %%
type(filtro1)
# Out:
# pandas.core.series.Series

# %%
type(filtro2)
# Out:
# pandas.core.series.Series

# %%
tabla_co2=data[filtro1&filtro2]

# %%
tabla_co2
# Out:
#        Country Name Country Code                          Indicator Name  \
# 166502      Ecuador          ECU  CO2 emissions (metric tons per capita)
#
#         Indicator Code      1960      1961      1962      1963     1964  \
# 166502  EN.ATM.CO2E.PC  0.388034  0.352049  0.325337  0.362722  0.42067
#
#             1965  ...      2010      2011      2012      2013      2014  2015  \
# 166502  0.433744  ...  2.441362  2.543911  2.473495  2.617689  2.761702   NaN
#
#         2016  2017  2018  Unnamed: 63
# 166502   NaN   NaN   NaN          NaN
#
# [1 rows x 64 columns]

# %%
plt.plot(tabla_co2.iloc[0,4:63].index.tolist(),tabla_co2.iloc[0,4:63].values.tolist())
plt.xlabel("Años")
plt.ylabel("Toneladas métricas per capita")
plt.title("Emisiones de CO2 en Ecuador (1960-2018)")
plt.show()

# %%
plt.bar(tabla_co2.iloc[0,53:63].index.tolist(),tabla_co2.iloc[0,53:63].values.tolist())
plt.xlabel("Años")
plt.ylabel("Toneladas métricas per capita")
plt.title("Emisiones de CO2 en Ecuador (2009-2018)")
plt.show()

# %% [markdown]
# ### Emisiones de CO2 en el mundo en el año 2014

# %%
co2_indicador='CO2 emissions \(metric tons per capita\)'
filtro1=data['Indicator Name'].str.contains(co2_indicador)

# %%
plt.hist(data[filtro1]['2014'], 10, density=False, facecolor='green')
plt.xlabel("Toneladas métricas per capita")
plt.ylabel("Número de países")
plt.title("Emisiones de CO2 en el año 2014")
# Out:
# Text(0.5, 1.0, 'Emisiones de CO2 en el año 2014')

# %% [markdown]
# ### Valor medio de emisiones en el año 2014

# %%
data[filtro1]['2014'].mean()
# Out:
# 4.8748918668231065

# %% [markdown]
# ### Producto interno bruto en Ecuador

# %%
gdp_indicador='GDP per capita \(constant 2010 US\$\)'
gdp_codigo_pais='ECU'
filtro3=data['Indicator Name'].str.contains(gdp_indicador)
filtro4=data['Country Code'].str.contains(gdp_codigo_pais)

# %%
tabla_gdp=data[filtro3&filtro4]

# %%
tabla_gdp
# Out:
#        Country Name Country Code                      Indicator Name  \
# 166816      Ecuador          ECU  GDP per capita (constant 2010 US$)
#
#         Indicator Code         1960         1961         1962         1963  \
# 166816  NY.GDP.PCAP.KD  2237.081852  2285.691581  2330.347676  2311.782068
#
#                1964        1965  ...         2010         2011         2012  \
# 166816  2412.060481  2419.57711  ...  4657.302361  4943.422704  5140.262907
#
#                2013         2014         2015         2016        2017  2018  \
# 166816  5311.212121  5428.714031  5352.876457  5209.559153  5256.02153   NaN
#
#         Unnamed: 63
# 166816          NaN
#
# [1 rows x 64 columns]

# %%
plt.plot(tabla_gdp.iloc[0,4:63].index.tolist(),tabla_gdp.iloc[0,4:63].values.tolist())
plt.xlabel("Años")
plt.ylabel("Producto interno bruto (constante 2010 en dólares)")
plt.title("Producto Interno Bruto Ecuador (1960-2018)")
plt.show()

# %%
plt.bar(tabla_gdp.iloc[0,53:63].index.tolist(),tabla_gdp.iloc[0,53:63].values.tolist())
plt.xlabel("Años")
plt.ylabel("Producto interno bruto (constante 2010 en dólares)")
plt.title("Producto Interno Bruto Ecuador (2009-2018)")
plt.show()

# %% [markdown]
# ### Producto interno bruto en el mundo año 2014

# %%
gdp_indicador='GDP per capita \(constant 2010 US\$\)'
filtro3=data['Indicator Name'].str.contains(gdp_indicador)

# %%
plt.hist(data[filtro3]['2014'], 10, density=False, facecolor='green')
plt.xlabel("Producto interno bruto (constante 2010 en dólares)")
plt.ylabel("Número de países")
plt.title("Producto Interno Bruto en el año 2014")
# Out:
# Text(0.5, 1.0, 'Producto Interno Bruto en el año 2014')

# %% [markdown]
# ### Valor medio del producto interno bruto en el 2014

# %%
data[filtro3]['2014'].mean()
# Out:
# 14259.790839039573

# %% [markdown]
# ### Análisis correlacional entre las emisiones de CO2 y el Producto interno bruto en Ecuador

# %%
x=tabla_gdp.iloc[0,4:63].values.tolist()
y=tabla_co2.iloc[0,4:63].values.tolist()

# %%
plt.scatter(x,y)
plt.xlabel("Producto interno bruto (constante 2010 en dólares)")
plt.ylabel("Toneladas métricas per capita de CO2")
plt.title("Gráfico correlacional CO2 vs PIB en Ecuador")
# Out:
# Text(0.5, 1.0, 'Gráfico correlacional CO2 vs PIB en Ecuador')

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# De acuerdo a los gráficos anteriormente elaborados, en el gráfico correlacional se puede apreciar un modelo de regresión lineal entre las dos variables analizadas. Esto significa que existe una correlación alta entre las emisiones de CO2 y el PIB en Ecuador, lo que podría significar que existe una relación de dependencia entre ambas variables.

# %% [markdown]
# A menor PIB, puede haber una menor cantidad de emisiones de CO2 a la atmósfera en Ecuador. Mientras que, al contrario, a un mayor PIB, las emisiones de CO2 aumentarían.

# %% [markdown]
# ## Fuente: Banco Mundial
